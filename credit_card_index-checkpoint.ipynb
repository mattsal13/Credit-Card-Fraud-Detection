# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

# %%
#read the database
df=pd.read_csv("/Users/Matt/Documents/GitHub/Credit-Card-Fraud-Detection/creditcard.csv")
#information about the database
print("There are", len(df), "observations in the data set.")
print("The columns are", df.columns)
# Out:
# There are 284807 observations in the data set.
# The columns are Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#the type of each column
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
#the shape of the database
df.shape
# Out:
# (284807, 31)

# %%
#Information of the database
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
#Remove missing values
df.dropna()
#We have the same shape (284807, 31). so there is no missing value.
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
#to make sure that there is no missing value
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#check how many classes that we have and what is the value of each class.
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#plot the classes
df["Class"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#plot 
sns.relplot(x='Amount', y='Time', hue='Class', data=df)

# %%
#plot amount according to class
#There are two classes 0 and 1
plt.figure(figsize = (8,8))


plt.scatter(df.Amount, df.Class, marker='+',color='red')


plt.xlabel("Amount", fontsize =16)


plt.ylabel("Class", fontsize = 16)


plt.show()

# %%
## First import the package
from sklearn.model_selection import train_test_split

# %%
###Separate features
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
## Now split the data
## Have 20% for testing
## Set 40 as the random state
## and stratify the split
X_train, X_test, y_train, y_test=train_test_split(X,y,
                                                  test_size=.2,
                                                  random_state=40,
                                                  shuffle=True,
                                                  stratify=y)

# %%
#Standardize the X_train
#from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)

# %%
## import the logistic regression method
from sklearn.linear_model import LogisticRegression

# %%
## Make a model instance here
Lreg=LogisticRegression()

# %%
## Fit the model here
Lreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#Standardize the X_test
X_test= scaler.transform(X_test)

# %%
## get the predictions
y_pred=Lreg.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#predict the probabilities
y_pred_prob=Lreg.predict_proba(X_test)
y_pred_prob
# Out:
# array([[9.99907058e-01, 9.29416966e-05],
#        [9.99976085e-01, 2.39152281e-05],
#        [9.99899860e-01, 1.00139794e-04],
#        ...,
#        [9.99937682e-01, 6.23177502e-05],
#        [9.99840614e-01, 1.59386277e-04],
#        [9.99718330e-01, 2.81669581e-04]])

# %%
# now we can get the confusion matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[56856     8]
#  [   47    51]]

# %%
# now we can get the accuracy_score
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9990344440153085

# %%
# now we can get the classification_report to know the precision, the recall, the f1-score, the support
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.86      0.52      0.65        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.76      0.82     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# ---------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Keras. 

from keras import models
from keras import layers
from keras import optimizers
from keras import losses
from keras import metrics

## For plotting
import matplotlib.pyplot as plt
from seaborn import set_style

## This sets the plot style
## to have a grid on a white background
set_style("white")

## Define categorical funcion. This prepares entries for tensor analysis. 

def to_categorical(y):
    return tf.keras.utils.to_categorical(y)

# %%
credit_card_df = pd.read_csv("/Users/Matt/Documents/GitHub/Credit-Card-Fraud-Detection/creditcard.csv")
credit_card_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card_df.value_counts('Class')
# Out:
# Class
# 0    284315
# 1       492
# dtype: int64

# %%
## Empty model
model = models.Sequential()

# %%
## Make the layers. ONLY RUN THIS ONCE. Make sure the input_shape is correct matches the number of features.

model.add(layers.Dense(16, activation='relu', input_shape=(30,)))

model.add(layers.Dense(16, activation='relu'))

model.add(layers.Dense(2, activation='softmax'))

# %%
# Gives a model summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                496
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 802
# Trainable params: 802
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Here we compile the model. We use binary cross-entropy. 

model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
# Features 

X = np.array(credit_card_df.iloc[:,:-1]).reshape(-1, 30)
y = np.array(credit_card_df.iloc[:,-1]).reshape(-1, 1)

## Make sure these are numpy arrays

print(np.shape(X), type(X))
print(np.shape(y), type(y))
# Out:
# (284807, 30) <class 'numpy.ndarray'>
# (284807, 1) <class 'numpy.ndarray'>

# %%
# Train/test split. 

from sklearn.model_selection import train_test_split

X_train_train,X_val,y_train_train,y_val = train_test_split(X, y,
                                                          test_size=.2,
                                                          shuffle=True,
                                                          stratify=y,
                                                          random_state=440)

# Make sure the shapes are compatible with the model. 

print(np.shape(X_train_train), type(X_train_train))
print(np.shape(y_train_train), type(y_train_train))
print(np.shape(X_val), type(X_val))
print(np.shape(y_val), type(y_val))
print('\n\n')
print(np.shape(to_categorical(y_train_train)), type(to_categorical(y_train_train)))
print(np.shape(to_categorical(y_val)), type(to_categorical(y_val)))
# Out:
# (227845, 30) <class 'numpy.ndarray'>
# (227845, 1) <class 'numpy.ndarray'>
# (56962, 30) <class 'numpy.ndarray'>
# (56962, 1) <class 'numpy.ndarray'>
#
#
#
# (227845, 2) <class 'numpy.ndarray'>
# (56962, 2) <class 'numpy.ndarray'>

# %%
# Fitting the data. 

history = model.fit(X_train_train,
                        to_categorical(y_train_train),
                        epochs = 100,
                        batch_size = 512,
                        validation_data=(X_val,to_categorical(y_val)))
# Out:
# Epoch 1/100
# 446/446 [==============================] - 16s 2ms/step - loss: 7.7661 - accuracy: 0.9935 - val_loss: 0.2801 - val_accuracy: 0.9983
# Epoch 2/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.1195 - accuracy: 0.9983 - val_loss: 0.0341 - val_accuracy: 0.9983
# Epoch 3/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0441 - accuracy: 0.9983 - val_loss: 0.0328 - val_accuracy: 0.9983
# Epoch 4/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0622 - accuracy: 0.9983 - val_loss: 0.0289 - val_accuracy: 0.9983
# Epoch 5/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0303 - accuracy: 0.9983 - val_loss: 0.0331 - val_accuracy: 0.9983
# Epoch 6/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0624 - accuracy: 0.9983 - val_loss: 0.0366 - val_accuracy: 0.9983
# Epoch 7/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0302 - accuracy: 0.9984 - val_loss: 0.0324 - val_accuracy: 0.9983
# Epoch 8/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.1631 - accuracy: 0.9945 - val_loss: 0.0219 - val_accuracy: 0.9983
# Epoch 9/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0548 - accuracy: 0.9979 - val_loss: 0.0313 - val_accuracy: 0.9983
# Epoch 10/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0947 - accuracy: 0.9963 - val_loss: 0.0590 - val_accuracy: 0.9983
# Epoch 11/100
# 446/446 [==============================] - 1s 2ms/step - loss: 0.0819 - accuracy: 0.9951 - val_loss: 0.0198 - val_accuracy: 0.9983
# Epoch 12/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0271 - accuracy: 0.9983 - val_loss: 0.0268 - val_accuracy: 0.9983
# Epoch 13/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0311 - accuracy: 0.9983 - val_loss: 0.0704 - val_accuracy: 0.9983
# Epoch 14/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0264 - accuracy: 0.9982 - val_loss: 0.0163 - val_accuracy: 0.9983
# Epoch 15/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0237 - accuracy: 0.9983 - val_loss: 0.0221 - val_accuracy: 0.9983
# Epoch 16/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0236 - accuracy: 0.9983 - val_loss: 0.0160 - val_accuracy: 0.9983
# Epoch 17/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0230 - accuracy: 0.9982 - val_loss: 0.0135 - val_accuracy: 0.9983
# Epoch 18/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0188 - accuracy: 0.9984 - val_loss: 0.0149 - val_accuracy: 0.9983
# Epoch 19/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0238 - accuracy: 0.9981 - val_loss: 0.0130 - val_accuracy: 0.9983
# Epoch 20/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0247 - accuracy: 0.9984 - val_loss: 0.0173 - val_accuracy: 0.9983
# Epoch 21/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0183 - accuracy: 0.9982 - val_loss: 0.0128 - val_accuracy: 0.9983
# Epoch 22/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0754 - accuracy: 0.9967 - val_loss: 0.0320 - val_accuracy: 0.9983
# Epoch 23/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.4923 - accuracy: 0.9942 - val_loss: 0.0140 - val_accuracy: 0.9983
# Epoch 24/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.1002 - accuracy: 0.9962 - val_loss: 0.0136 - val_accuracy: 0.9983
# Epoch 25/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.1003 - accuracy: 0.9933 - val_loss: 0.0211 - val_accuracy: 0.9983
# Epoch 26/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0363 - accuracy: 0.9965 - val_loss: 0.0133 - val_accuracy: 0.9983
# Epoch 27/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0203 - accuracy: 0.9970 - val_loss: 0.0370 - val_accuracy: 0.9983
# Epoch 28/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0270 - accuracy: 0.9966 - val_loss: 0.0157 - val_accuracy: 0.9983
# Epoch 29/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0320 - accuracy: 0.9921 - val_loss: 0.0190 - val_accuracy: 0.9983
# Epoch 30/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0245 - accuracy: 0.9955 - val_loss: 0.0192 - val_accuracy: 0.9983
# Epoch 31/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0510 - accuracy: 0.9906 - val_loss: 0.1656 - val_accuracy: 0.9983
# Epoch 32/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0340 - accuracy: 0.9936 - val_loss: 0.0181 - val_accuracy: 0.9983
# Epoch 33/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0160 - accuracy: 0.9984 - val_loss: 0.0450 - val_accuracy: 0.9984
# Epoch 34/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.1779 - accuracy: 0.9859 - val_loss: 0.1195 - val_accuracy: 0.9983
# Epoch 35/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0500 - accuracy: 0.9957 - val_loss: 0.0197 - val_accuracy: 0.9984
# Epoch 36/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0372 - accuracy: 0.9930 - val_loss: 0.0223 - val_accuracy: 0.9983
# Epoch 37/100
# 446/446 [==============================] - 1s 2ms/step - loss: 0.0228 - accuracy: 0.9964 - val_loss: 0.0119 - val_accuracy: 0.9983
# Epoch 38/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0260 - accuracy: 0.9954 - val_loss: 0.0103 - val_accuracy: 0.9985
# Epoch 39/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0234 - accuracy: 0.9952 - val_loss: 0.0125 - val_accuracy: 0.9984
# Epoch 40/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0222 - accuracy: 0.9962 - val_loss: 0.0130 - val_accuracy: 0.9985
# Epoch 41/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0225 - accuracy: 0.9967 - val_loss: 0.0103 - val_accuracy: 0.9985
# Epoch 42/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0276 - accuracy: 0.9956 - val_loss: 0.0096 - val_accuracy: 0.9985
# Epoch 43/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0375 - accuracy: 0.9906 - val_loss: 0.0096 - val_accuracy: 0.9985
# Epoch 44/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0685 - accuracy: 0.9950 - val_loss: 0.0129 - val_accuracy: 0.9984
# Epoch 45/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0167 - accuracy: 0.9959 - val_loss: 0.0183 - val_accuracy: 0.9983
# Epoch 46/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0456 - accuracy: 0.9907 - val_loss: 0.0101 - val_accuracy: 0.9984
# Epoch 47/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0416 - accuracy: 0.9919 - val_loss: 0.0075 - val_accuracy: 0.9986
# Epoch 48/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0557 - accuracy: 0.9913 - val_loss: 0.0168 - val_accuracy: 0.9985
# Epoch 49/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0251 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 0.9986
# Epoch 50/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0391 - accuracy: 0.9925 - val_loss: 0.0047 - val_accuracy: 0.9992
# Epoch 51/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0439 - accuracy: 0.9909 - val_loss: 0.0329 - val_accuracy: 0.9983
# Epoch 52/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0277 - accuracy: 0.9972 - val_loss: 0.0443 - val_accuracy: 0.9985
# Epoch 53/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0524 - accuracy: 0.9960 - val_loss: 0.0305 - val_accuracy: 0.9985
# Epoch 54/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0424 - accuracy: 0.9957 - val_loss: 0.0140 - val_accuracy: 0.9985
# Epoch 55/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0445 - accuracy: 0.9948 - val_loss: 0.0055 - val_accuracy: 0.9990
# Epoch 56/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0482 - accuracy: 0.9916 - val_loss: 0.0123 - val_accuracy: 0.9987
# Epoch 57/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0257 - accuracy: 0.9950 - val_loss: 0.0293 - val_accuracy: 0.9984
# Epoch 58/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0277 - accuracy: 0.9957 - val_loss: 0.0271 - val_accuracy: 0.9984
# Epoch 59/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0329 - accuracy: 0.9976 - val_loss: 0.0196 - val_accuracy: 0.9988
# Epoch 60/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.0792 - accuracy: 0.9907 - val_loss: 0.0212 - val_accuracy: 0.9988
# Epoch 61/100
# 446/446 [==============================] - 1s 2ms/step - loss: 0.0728 - accuracy: 0.9971 - val_loss: 0.0756 - val_accuracy: 0.9985
# Epoch 62/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.1192 - accuracy: 0.9955 - val_loss: 0.2722 - val_accuracy: 0.9986
# Epoch 63/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.3290 - accuracy: 0.9961 - val_loss: 0.1732 - val_accuracy: 0.9986
# Epoch 64/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.3892 - accuracy: 0.9875 - val_loss: 0.1616 - val_accuracy: 0.9985
# Epoch 65/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5084 - accuracy: 0.9950 - val_loss: 0.1536 - val_accuracy: 0.9988
# Epoch 66/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5002 - accuracy: 0.9930 - val_loss: 0.4151 - val_accuracy: 0.9985
# Epoch 67/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5648 - accuracy: 0.9986 - val_loss: 0.2593 - val_accuracy: 0.9982
# Epoch 68/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5163 - accuracy: 0.9980 - val_loss: 0.1345 - val_accuracy: 0.9988
# Epoch 69/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2282 - accuracy: 0.9943 - val_loss: 0.0628 - val_accuracy: 0.9986
# Epoch 70/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5111 - accuracy: 0.9895 - val_loss: 0.0668 - val_accuracy: 0.9988
# Epoch 71/100
# 446/446 [==============================] - 1s 2ms/step - loss: 0.2192 - accuracy: 0.9950 - val_loss: 0.1571 - val_accuracy: 0.9985
# Epoch 72/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2091 - accuracy: 0.9980 - val_loss: 0.4740 - val_accuracy: 0.9984
# Epoch 73/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.9941 - val_loss: 0.5187 - val_accuracy: 0.9987
# Epoch 74/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.0808 - accuracy: 0.9923 - val_loss: 0.0715 - val_accuracy: 0.9988
# Epoch 75/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.6156 - accuracy: 0.9875 - val_loss: 0.0501 - val_accuracy: 0.9987
# Epoch 76/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.8783 - accuracy: 0.9895 - val_loss: 0.5463 - val_accuracy: 0.9985
# Epoch 77/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.7642 - accuracy: 0.9978 - val_loss: 0.5731 - val_accuracy: 0.9985
# Epoch 78/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.6871 - accuracy: 0.9957 - val_loss: 0.2777 - val_accuracy: 0.9987
# Epoch 79/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.7626 - accuracy: 0.9985 - val_loss: 0.2379 - val_accuracy: 0.9984
# Epoch 80/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5764 - accuracy: 0.9943 - val_loss: 0.3648 - val_accuracy: 0.9985
# Epoch 81/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.0079 - accuracy: 0.9932 - val_loss: 0.6196 - val_accuracy: 0.9984
# Epoch 82/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.7247 - accuracy: 0.9950 - val_loss: 0.5350 - val_accuracy: 0.9982
# Epoch 83/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.8529 - accuracy: 0.9945 - val_loss: 0.6106 - val_accuracy: 0.9983
# Epoch 84/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.2276 - accuracy: 0.9922 - val_loss: 0.4957 - val_accuracy: 0.9984
# Epoch 85/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.7569 - accuracy: 0.9933 - val_loss: 0.5021 - val_accuracy: 0.9985
# Epoch 86/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.0836 - accuracy: 0.9983 - val_loss: 0.1041 - val_accuracy: 0.9984
# Epoch 87/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.9577 - accuracy: 0.9917 - val_loss: 0.0955 - val_accuracy: 0.9988
# Epoch 88/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.2817 - accuracy: 0.9924 - val_loss: 0.2933 - val_accuracy: 0.9987
# Epoch 89/100
# 446/446 [==============================] - 1s 2ms/step - loss: 0.7391 - accuracy: 0.9935 - val_loss: 0.5843 - val_accuracy: 0.9986
# Epoch 90/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.0537 - accuracy: 0.9958 - val_loss: 0.2177 - val_accuracy: 0.9986
# Epoch 91/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.0159 - accuracy: 0.9921 - val_loss: 0.6570 - val_accuracy: 0.9985
# Epoch 92/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.0052 - accuracy: 0.9973 - val_loss: 0.5854 - val_accuracy: 0.9987
# Epoch 93/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.1781 - accuracy: 0.9907 - val_loss: 0.5992 - val_accuracy: 0.9987
# Epoch 94/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.8770 - accuracy: 0.9962 - val_loss: 0.5008 - val_accuracy: 0.9987
# Epoch 95/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.1962 - accuracy: 0.9897 - val_loss: 0.2254 - val_accuracy: 0.9986
# Epoch 96/100
# 446/446 [==============================] - 1s 1ms/step - loss: 0.5956 - accuracy: 0.9979 - val_loss: 0.5933 - val_accuracy: 0.9986
# Epoch 97/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.0555 - accuracy: 0.9981 - val_loss: 0.1327 - val_accuracy: 0.9989
# Epoch 98/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.2610 - accuracy: 0.9892 - val_loss: 0.2375 - val_accuracy: 0.9987
# Epoch 99/100
# 446/446 [==============================] - 1s 2ms/step - loss: 0.7598 - accuracy: 0.9959 - val_loss: 0.2345 - val_accuracy: 0.9987
# Epoch 100/100
# 446/446 [==============================] - 1s 1ms/step - loss: 1.4893 - accuracy: 0.9927 - val_loss: 0.4955 - val_accuracy: 0.9987

# %%
# Examine the results. 

history_dict = history.history

print(history_dict.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# That's... intersting. 

set_style("whitegrid")

plt.figure(figsize = (10,6))

plt.scatter(range(1,101), history_dict['accuracy'], label = "Training Accuracy")
plt.scatter(range(1,101), history_dict['val_accuracy'], label = "Validation Set Accuracy")

plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Accuracy", fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.legend(fontsize=18)

plt.show()

# %%
plt.figure(figsize = (10,6))

plt.scatter(range(1,101), history_dict['loss'], label = "Training Loss")
plt.scatter(range(1,101), history_dict['val_loss'], label = "Validation Set Loss")

plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Loss Function Value", fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.legend(fontsize=18)

plt.show()
